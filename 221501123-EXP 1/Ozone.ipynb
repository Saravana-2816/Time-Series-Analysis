# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("D:/221501124/OzoneHole_Data.csv")

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           42 non-null     int64
#  1   Hole Area      42 non-null     float64
#  2   Minimum Ozone  42 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.1 KB
# None
#               Year  Hole Area  Minimum Ozone
# count    42.000000  42.000000      42.000000
# mean   2000.119048  18.438095     131.142857
# std      12.684160   7.418499      32.595923
# min    1979.000000   0.100000      92.300000
# 25%    1989.250000  15.000000     108.725000
# 50%    2000.500000  20.950000     121.000000
# 75%    2010.750000  23.575000     145.325000
# max    2021.000000  26.600000     225.000000

# %%
df.head()
# Out:
#    Year  Hole Area  Minimum Ozone
# 0  1979        0.1          225.0
# 1  1980        1.4          203.0
# 2  1981        0.6          209.5
# 3  1982        4.8          185.0
# 4  1983        7.9          172.9

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x="Year", y="Hole Area", data=df, marker='o', label='Hole Area')
plt.title("Trend of Ozone Hole Area Over Years", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Hole Area (Million km²)", fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x="Year", y="Minimum Ozone", data=df, marker='o', color='orange', label='Minimum Ozone')
plt.title("Trend of Minimum Ozone Levels Over Years", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Minimum Ozone (Dobson Units)", fontsize=12)
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Between Variables", fontsize=14)
plt.show()
